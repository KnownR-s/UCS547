# %%
import numba
print(numba.__version__)
# Out:
# 0.60.0

# %% [markdown]
# # Question 1

# %%
import numpy as np
import math
import time

from numba import cuda

# Array Size
N = 5000000

# -----------------------------
# FLOAT32 VERSION
# -----------------------------

# Create random float32 array
x_float32 = np.random.rand(N).astype(np.float32)

# CPU COMPUTATION
start_cpu = time.time()

cpu_result32 = x_float32**2 + 3*x_float32 + 5

end_cpu = time.time()

cpu_time32 = end_cpu - start_cpu

# GPU KERNEL
@cuda.jit
def compute_kernel32(input_array, output_array):

    idx = cuda.grid(1)

    if idx < input_array.size:
        x = input_array[idx]
        output_array[idx] = x*x + 3*x + 5

# Allocate output array
gpu_result32 = np.zeros_like(x_float32)

# Copy data to GPU
d_input32 = cuda.to_device(x_float32)
d_output32 = cuda.device_array_like(gpu_result32)

# Kernel launch configuration
threads_per_block = 256
blocks_per_grid = math.ceil(N / threads_per_block)

# GPU EXECUTION
start_gpu = time.time()

compute_kernel32[blocks_per_grid, threads_per_block](
    d_input32,
    d_output32
)

cuda.synchronize()

end_gpu = time.time()

gpu_time32 = end_gpu - start_gpu

# Copy result back
gpu_result32 = d_output32.copy_to_host()

print("FLOAT32 RESULTS")
print("----------------")
print("CPU Time :", cpu_time32, "seconds")
print("GPU Time :", gpu_time32, "seconds")

# -----------------------------
# FLOAT64 VERSION
# -----------------------------

x_float64 = np.random.rand(N).astype(np.float64)

# CPU
start_cpu = time.time()

cpu_result64 = x_float64**2 + 3*x_float64 + 5

end_cpu = time.time()

cpu_time64 = end_cpu - start_cpu

# GPU KERNEL
@cuda.jit
def compute_kernel64(input_array, output_array):

    idx = cuda.grid(1)

    if idx < input_array.size:
        x = input_array[idx]
        output_array[idx] = x*x + 3*x + 5

gpu_result64 = np.zeros_like(x_float64)

d_input64 = cuda.to_device(x_float64)
d_output64 = cuda.device_array_like(gpu_result64)

start_gpu = time.time()

compute_kernel64[blocks_per_grid, threads_per_block](
    d_input64,
    d_output64
)

cuda.synchronize()

end_gpu = time.time()

gpu_time64 = end_gpu - start_gpu

gpu_result64 = d_output64.copy_to_host()

print("\nFLOAT64 RESULTS")
print("----------------")
print("CPU Time :", cpu_time64, "seconds")
print("GPU Time :", gpu_time64, "seconds")
# Out:
# FLOAT32 RESULTS
# ----------------
# CPU Time : 0.041297197341918945 seconds
# GPU Time : 2.5014522075653076 seconds
#
# FLOAT64 RESULTS
# ----------------
# CPU Time : 0.05765795707702637 seconds
# GPU Time : 0.09522867202758789 seconds

# %% [markdown]
# # Question 2

# %%
import numpy as np
import time

from numba import njit

# -----------------------------------
# Generate Random Data
# -----------------------------------

N = 1000000

data = np.random.randint(0, 100, N)

bins = 100

# -----------------------------------
# PURE PYTHON HISTOGRAM
# -----------------------------------

def python_histogram(data, bins):

    hist = [0] * bins

    for value in data:
        hist[value] += 1

    return hist

# -----------------------------------
# NUMPY HISTOGRAM
# -----------------------------------

def numpy_histogram(data, bins):

    hist, _ = np.histogram(data, bins=bins, range=(0, bins))

    return hist

# -----------------------------------
# NUMBA HISTOGRAM
# -----------------------------------

@njit
def numba_histogram(data, bins):

    hist = np.zeros(bins, dtype=np.int64)

    for i in range(len(data)):
        hist[data[i]] += 1

    return hist

# -----------------------------------
# PURE PYTHON TIMING
# -----------------------------------

start = time.time()

hist_python = python_histogram(data, bins)

end = time.time()

python_time = end - start

print("Pure Python Time :", python_time, "seconds")

# -----------------------------------
# NUMPY TIMING
# -----------------------------------

start = time.time()

hist_numpy = numpy_histogram(data, bins)

end = time.time()

numpy_time = end - start

print("NumPy Time :", numpy_time, "seconds")

# -----------------------------------
# NUMBA TIMING
# -----------------------------------

# First call includes compilation time
numba_histogram(data, bins)

start = time.time()

hist_numba = numba_histogram(data, bins)

end = time.time()

numba_time = end - start

print("Numba Time :", numba_time, "seconds")

# -----------------------------------
# CORRECTNESS CHECK
# -----------------------------------

print("\nCorrectness Check")

print("Python vs NumPy :",
      np.array_equal(np.array(hist_python), hist_numpy))

print("NumPy vs Numba :",
      np.array_equal(hist_numpy, hist_numba))
# Out:
# Pure Python Time : 0.10905575752258301 seconds
# NumPy Time : 0.018683195114135742 seconds
# Numba Time : 0.0011844635009765625 seconds
#
# Correctness Check
# Python vs NumPy : True
# NumPy vs Numba : True

# %% [markdown]
# # Question 3

# %%
import random
import time

from numba import njit

# -----------------------------------------
# PURE PYTHON VERSION
# -----------------------------------------

def monte_carlo_pi_python(nsamples):

    inside_circle = 0

    for _ in range(nsamples):

        x = random.random()
        y = random.random()

        if x*x + y*y < 1:
            inside_circle += 1

    pi_estimate = 4 * inside_circle / nsamples

    return pi_estimate

# -----------------------------------------
# NUMBA VERSION
# -----------------------------------------

@njit
def monte_carlo_pi_numba(nsamples):

    inside_circle = 0

    for _ in range(nsamples):

        x = random.random()
        y = random.random()

        if x*x + y*y < 1:
            inside_circle += 1

    pi_estimate = 4 * inside_circle / nsamples

    return pi_estimate

# -----------------------------------------
# NUMBER OF SAMPLES
# -----------------------------------------

N = 5000000

# -----------------------------------------
# PURE PYTHON TIMING
# -----------------------------------------

start = time.time()

pi_python = monte_carlo_pi_python(N)

end = time.time()

python_time = end - start

print("PURE PYTHON")
print("Estimated PI :", pi_python)
print("Execution Time :", python_time, "seconds")

# -----------------------------------------
# NUMBA FIRST RUN
# (includes compilation time)
# -----------------------------------------

monte_carlo_pi_numba(10)

# -----------------------------------------
# NUMBA TIMING
# -----------------------------------------

start = time.time()

pi_numba = monte_carlo_pi_numba(N)

end = time.time()

numba_time = end - start

print("\nNUMBA")
print("Estimated PI :", pi_numba)
print("Execution Time :", numba_time, "seconds")

# -----------------------------------------
# SPEEDUP FACTOR
# -----------------------------------------

speedup = python_time / numba_time

print("\nSpeedup Factor :", speedup)
# Out:
# PURE PYTHON
# Estimated PI : 3.1409792
# Execution Time : 1.6560084819793701 seconds
#
# NUMBA
# Estimated PI : 3.1410296
# Execution Time : 0.05477476119995117 seconds
#
# Speedup Factor : 30.23305708142177

# %% [markdown]
# # Question 4

# %%
import numpy as np
import time

from numba import vectorize

# ------------------------------------------
# VECTORIZE FUNCTION
# ------------------------------------------

@vectorize(['int64(int64)'])
def adjust_brightness(pixel_value):

    new_value = int(pixel_value * 1.2)

    if new_value > 255:
        return 255

    return new_value

# ------------------------------------------
# GENERATE PIXEL ARRAY
# ------------------------------------------

N = 10000000

pixels = np.random.randint(
            0,
            256,
            N,
            dtype=np.int64
         )

# ------------------------------------------
# TIMING
# ------------------------------------------

start = time.time()

bright_pixels = adjust_brightness(pixels)

end = time.time()

print("Execution Time :", end - start, "seconds")

print("\nFirst 10 Original Pixels:")
print(pixels[:10])

print("\nFirst 10 Brightened Pixels:")
print(bright_pixels[:10])
# Out:
# Execution Time : 0.024892568588256836 seconds
#
# First 10 Original Pixels:
# [230 148 232  56 109  93  27  41  24 125]
#
# First 10 Brightened Pixels:
# [255 177 255  67 130 111  32  49  28 150]

# %%
import numpy as np
import time

from numba import vectorize

# ------------------------------------------
# PARALLEL VERSION
# ------------------------------------------

@vectorize(['int64(int64)'], target='parallel')
def adjust_brightness_parallel(pixel_value):

    new_value = int(pixel_value * 1.2)

    if new_value > 255:
        return 255

    return new_value

# ------------------------------------------
# GENERATE DATA
# ------------------------------------------

N = 10000000

pixels = np.random.randint(
            0,
            256,
            N,
            dtype=np.int64
         )

# ------------------------------------------
# TIMING
# ------------------------------------------

start = time.time()

bright_pixels = adjust_brightness_parallel(pixels)

end = time.time()

print("Parallel Execution Time :",
      end - start,
      "seconds")
# Out:
# Parallel Execution Time : 0.02680802345275879 seconds

# %% [markdown]
# # Question 5

# %%
import numpy as np
import time

from numba import njit

# ---------------------------------------
# SYNTHETIC DATA
# ---------------------------------------

samples = 100000
features = 10

np.random.seed(42)

X = np.random.randn(samples, features)

# Binary labels {-1, +1}
y = np.random.choice([-1, 1], size=samples)

# ---------------------------------------
# PARAMETERS
# ---------------------------------------

learning_rate = 0.01
epochs = 100

# ---------------------------------------
# SIGMOID FUNCTION
# ---------------------------------------

def sigmoid(z):

    return 1 / (1 + np.exp(-z))

# ---------------------------------------
# NUMPY LOGISTIC REGRESSION
# ---------------------------------------

def logistic_regression_numpy(X, y):

    weights = np.zeros(X.shape[1])

    for _ in range(epochs):

        linear = np.dot(X, weights)

        predictions = sigmoid(linear)

        # Convert labels {-1,+1} to {0,1}
        y_binary = (y + 1) / 2

        gradient = np.dot(
                        X.T,
                        (predictions - y_binary)
                   ) / len(y)

        weights -= learning_rate * gradient

    return weights

# ---------------------------------------
# NUMBA VERSION
# ---------------------------------------

@njit
def logistic_regression_numba(X, y,
                              learning_rate,
                              epochs):

    weights = np.zeros(X.shape[1])

    for _ in range(epochs):

        linear = np.dot(X, weights)

        predictions = 1 / (1 + np.exp(-linear))

        y_binary = (y + 1) / 2

        gradient = np.dot(
                        X.T,
                        (predictions - y_binary)
                   ) / len(y)

        weights -= learning_rate * gradient

    return weights

# ---------------------------------------
# NUMPY TIMING
# ---------------------------------------

start = time.time()

weights_numpy = logistic_regression_numpy(X, y)

end = time.time()

numpy_time = end - start

print("NUMPY VERSION")
print("Execution Time :", numpy_time, "seconds")

# ---------------------------------------
# NUMBA FIRST RUN
# (Compilation)
# ---------------------------------------

logistic_regression_numba(
    X,
    y,
    learning_rate,
    1
)

# ---------------------------------------
# NUMBA TIMING
# ---------------------------------------

start = time.time()

weights_numba = logistic_regression_numba(
                    X,
                    y,
                    learning_rate,
                    epochs
                )

end = time.time()

numba_time = end - start

print("\nNUMBA VERSION")
print("Execution Time :", numba_time, "seconds")

# ---------------------------------------
# CORRECTNESS CHECK
# ---------------------------------------

difference = np.linalg.norm(
                weights_numpy - weights_numba
             )

print("\nDifference Between Weights :",
      difference)

# ---------------------------------------
# SPEEDUP
# ---------------------------------------

speedup = numpy_time / numba_time

print("\nSpeedup Factor :", speedup)
# Out:
# NUMPY VERSION
# Execution Time : 0.40935420989990234 seconds
#
# NUMBA VERSION
# Execution Time : 0.328399658203125 seconds
#
# Difference Between Weights : 8.261485383671575e-19
#
# Speedup Factor : 1.2465122897500232

# %% [markdown]
# # Question 6

# %%
import numpy as np
import math
import time

from numba import cuda

# -----------------------------------------
# MATRIX SIZE
# -----------------------------------------

N = 1024

# -----------------------------------------
# CREATE MATRICES
# -----------------------------------------

A = np.random.rand(N, N).astype(np.float32)
B = np.random.rand(N, N).astype(np.float32)

# Output matrix
C = np.zeros((N, N), dtype=np.float32)

# -----------------------------------------
# CUDA KERNEL
# -----------------------------------------

@cuda.jit
def matrix_add_kernel(A, B, C):

    row, col = cuda.grid(2)

    if row < C.shape[0] and col < C.shape[1]:

        C[row, col] = A[row, col] + B[row, col]

# -----------------------------------------
# COPY DATA TO GPU
# -----------------------------------------

d_A = cuda.to_device(A)
d_B = cuda.to_device(B)
d_C = cuda.device_array_like(C)

# -----------------------------------------
# THREADS AND BLOCKS
# -----------------------------------------

threads_per_block = (16, 16)

blocks_per_grid_x = math.ceil(N / threads_per_block[0])
blocks_per_grid_y = math.ceil(N / threads_per_block[1])

blocks_per_grid = (
    blocks_per_grid_x,
    blocks_per_grid_y
)

# -----------------------------------------
# EXECUTION TIME
# -----------------------------------------

start = time.time()

matrix_add_kernel[
    blocks_per_grid,
    threads_per_block
](
    d_A,
    d_B,
    d_C
)

cuda.synchronize()

end = time.time()

# -----------------------------------------
# COPY RESULT BACK
# -----------------------------------------

C = d_C.copy_to_host()

# -----------------------------------------
# OUTPUT
# -----------------------------------------

print("Execution Time :",
      end - start,
      "seconds")

print("\nSample Output:")

print("A[0][0] =", A[0][0])
print("B[0][0] =", B[0][0])
print("C[0][0] =", C[0][0])
# Out:
# Execution Time : 0.08435440063476562 seconds
#
# Sample Output:
# A[0][0] = 0.48813277
# B[0][0] = 0.9814017
# C[0][0] = 1.4695344
